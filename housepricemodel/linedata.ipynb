# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_boston

# %%
boston_path = "./data/housing.data"
boston_X,boston_Y= load_boston(boston_path,return_X_y=True)
# Out:
# /home/ouyangzhifei/anaconda3/envs/tensorflowgpu/lib/python3.6/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass return_X_y=./data/housing.data as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)

# %%
boston_X,boston_Y.shape
# Out:
# (array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  (506,))

# %%
feature=["CRIM","ZN","INDUS","CHAS","NOX","RM","AGE","DIS","RAD","TAX","PTRATIO","B","LSTAT"]
tag=["MEDV"]

# %%
data_x=pd.DataFrame(boston_X,columns=feature)
data_y=pd.DataFrame(boston_Y,columns=tag)

# %%
data_x
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
data_y
# Out:
#      MEDV
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
import seaborn as sns

# %%
sns.set(color_codes=True)
# sns.regplot(x=data_y,y=data_x[feature[0]],color='g',x_estimator=np.mean, logx=True, truncate=True)
# Out:
# <AxesSubplot:xlabel='MEDV', ylabel='CRIM'>

# %%
# sns.regplot(x=data_y,y=data_x[feature[1]],color='g',x_estimator=np.mean, logx=True, truncate=True)
# Out:
# <AxesSubplot:xlabel='MEDV', ylabel='ZN'>

# %%
# sns.regplot(x=data_y,y=data_x[feature[2]],color='g',x_estimator=np.mean, logx=True, truncate=True)
# Out:
# <AxesSubplot:xlabel='MEDV', ylabel='INDUS'>

# %%
# sns.regplot(x=data_y,y=data_x[feature[3]],color='g',x_estimator=np.mean, logx=True, truncate=True)

# %%
# sns.regplot(x=data_y,y=data_x[feature[4]],color='g',x_estimator=np.mean, logx=True, truncate=True)
# Out:
# <AxesSubplot:xlabel='MEDV', ylabel='NOX'>

# %%
# sns.regplot(x=data_y,y=data_x[feature[5]],color='g',x_estimator=np.mean, logx=True, truncate=True)
# Out:
# <AxesSubplot:xlabel='MEDV', ylabel='RM'>

# %%
# sns.regplot(x=data_y,y=data_x[feature[6]],color='g',x_estimator=np.mean, logx=True, truncate=True)

# %%
# sns.regplot(x=data_y,y=data_x[feature[7]],color='g',x_estimator=np.mean, logx=True, truncate=True)

# %%
# sns.regplot(x=data_y,y=data_x[feature[8]],color='g',x_estimator=np.mean, logx=True, truncate=True)

# %%
# sns.regplot(x=data_y,y=data_x[feature[9]],color='g',x_estimator=np.mean, logx=True, truncate=True)

# %%
# sns.regplot(x=data_y,y=data_x[feature[10]],color='g',x_estimator=np.mean, logx=True, truncate=True)

# %%
# sns.regplot(x=data_y,y=data_x[feature[11]],color='g',x_estimator=np.mean, logx=True, truncate=True)

# %%
# sns.regplot(x=data_y,y=data_x[feature[12]],color='g',x_estimator=np.mean, logx=True, truncate=True)
# Out:
# <AxesSubplot:xlabel='MEDV', ylabel='LSTAT'>

# %%
data_x[feature[0]]
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: CRIM, Length: 506, dtype: float64

# %%
data_x.shape
# Out:
# (506, 13)

# %%
data_y.shape
# Out:
# (506, 1)

# %%
#  Variables in order:
#  CRIM     per capita crime rate by town
#  ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#  INDUS    proportion of non-retail business acres per town
#  CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#  NOX      nitric oxides concentration (parts per 10 million)
#  RM       average number of rooms per dwelling
#  AGE      proportion of owner-occupied units built prior to 1940
#  DIS      weighted distances to five Boston employment centres
#  RAD      index of accessibility to radial highways
#  TAX      full-value property-tax rate per $10,000
#  PTRATIO  pupil-teacher ratio by town
#  B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#  LSTAT    % lower status of the population
#  MEDV     Median value of owner-occupied homes in $1000's
# import seaborn as sns

# %%
# # 设置绘图大小
# plt.style.use({'figure.figsize':(15,10)})
# # 绘制直方图,分15个分段
# data_x.hist(bins=15)
# # 绘制散点图
# sns.pairplot(data_x)

# %%
split_x=pd.concat([data_x["CRIM"],data_x["ZN"],data_x["INDUS"],data_x["NOX"],data_x["RM"],data_x["LSTAT"]],axis=1)

# %%
split_x.shape
# Out:
# (506, 6)

# %%
train_x=np.array(split_x)
train_y=np.array(data_y)

# %%
len(split_x.columns)
# Out:
# 6

# %%
split_x.shape
# Out:
# (506, 6)

# %%
for i in range(len(split_x.columns)):
    train_x[:,i] = (train_x[:,i] - train_x[:,i].min()) / (train_x[:,i].max() - train_x[:,i].min())

# %%
len(train_y)
# Out:
# 506

# %%
# for i in range(len(train_y)):
#     train_y[i,0]=(train_y[i,0] - train_y.min()) / (train_y.max() - train_y.min())

# %%
x = tf.placeholder(tf.float32,shape=[None,len(split_x.columns)],name="input_x")
y = tf.placeholder(tf.float32,shape=[None,1],name="input_y")

# %%
w = tf.Variable(tf.random_normal([len(split_x.columns),1],stddev=0.01,name="weight"))
b = tf.Variable(1.0,name="bias")

# %%
y_pred = tf.matmul(x,w)+b

# %%
# 定义学习率
LEARNING_RATE_BASE = 0.4  # 学习率基数,初始值
global_step = tf.Variable(0, trainable=False)  # 训练轮数
LEARNING_RATE_STEP = 10  # 学习率更新频率,一般为:总样本数/每轮输入的样本数,即样本数输入的轮数
LEARNING_RATE_DECAY = 0.99  # 学习率衰减率
# 定义指数衰减学习率
learning_rate = tf.train.exponential_decay(LEARNING_RATE_BASE, global_step, LEARNING_RATE_STEP, LEARNING_RATE_DECAY,
                                           staircase=False)

# %%
# learning_rate=0.01
epoch = 10
batch_size = len(train_y) // epoch
loss = tf.reduce_mean(tf.square(y-y_pred))
op = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss,global_step=global_step)

# %%
with tf.Session() as sess:
    loss_list=[]
    sess.run(tf.global_variables_initializer())
    for i in range(500):
        sess.run(op,feed_dict={x:train_x,y:train_y})
        LOSS, W ,B,LN= sess.run([loss, w, b,learning_rate], feed_dict={x:train_x,y:train_y})
        loss_list.append(LOSS)
        if i%10==0:
            log_str = "Epoch %d \t Loss=%.4g \t Bias=%.4g \t learning_rate=%.4g"
            print(log_str % (i, LOSS,B,LN))
#     for i in range(0,epoch+1):
#         start = i*batch_size
#         end = start+batch_size
#         sess.run(op,feed_dict={x:train_x[start:end],y:train_y[start:end]})
#         LOSS, W ,B= sess.run([loss, w, b], feed_dict={x:train_x[start:end],y:train_y[start:end]})    
#         log_str = "Epoch %d \t Loss=%.4g \t"
#         print(log_str % (i, LOSS))
    predict_list=[]
    target_list=[]
    for i in range(200):
        n = np.random.randint(506)  # 一共500条数据
        x_test = train_x[n]
        x_test = x_test.reshape(1, len(split_x.columns))
        predict = sess.run(y_pred, feed_dict={x: x_test})
        target = train_y[n]
        predict_list.append(predict[0][0])
        target_list.append(target[0])
# Out:
# Epoch 0 	 Loss=117.6 	 Bias=11.33 	 learning_rate=0.2398
# Epoch 10 	 Loss=57.11 	 Bias=16.11 	 learning_rate=0.2374
# Epoch 20 	 Loss=44.03 	 Bias=17.2 	 learning_rate=0.235
# Epoch 30 	 Loss=39.08 	 Bias=17.66 	 learning_rate=0.2326
# Epoch 40 	 Loss=36.58 	 Bias=17.82 	 learning_rate=0.2303
# Epoch 50 	 Loss=34.99 	 Bias=17.83 	 learning_rate=0.228
# Epoch 60 	 Loss=33.85 	 Bias=17.77 	 learning_rate=0.2257
# Epoch 70 	 Loss=32.99 	 Bias=17.67 	 learning_rate=0.2235
# Epoch 80 	 Loss=32.33 	 Bias=17.56 	 learning_rate=0.2212
# Epoch 90 	 Loss=31.81 	 Bias=17.45 	 learning_rate=0.219
# Epoch 100 	 Loss=31.41 	 Bias=17.34 	 learning_rate=0.2168
# Epoch 110 	 Loss=31.09 	 Bias=17.23 	 learning_rate=0.2147
# Epoch 120 	 Loss=30.84 	 Bias=17.13 	 learning_rate=0.2125
# Epoch 130 	 Loss=30.64 	 Bias=17.03 	 learning_rate=0.2104
# Epoch 140 	 Loss=30.48 	 Bias=16.94 	 learning_rate=0.2083
# Epoch 150 	 Loss=30.35 	 Bias=16.85 	 learning_rate=0.2062
# Epoch 160 	 Loss=30.25 	 Bias=16.77 	 learning_rate=0.2041
# Epoch 170 	 Loss=30.17 	 Bias=16.7 	 learning_rate=0.2021
# Epoch 180 	 Loss=30.1 	 Bias=16.63 	 learning_rate=0.2001
# Epoch 190 	 Loss=30.05 	 Bias=16.56 	 learning_rate=0.1981
# Epoch 200 	 Loss=30 	 Bias=16.5 	 learning_rate=0.1961
# Epoch 210 	 Loss=29.97 	 Bias=16.44 	 learning_rate=0.1941
# Epoch 220 	 Loss=29.94 	 Bias=16.39 	 learning_rate=0.1922
# Epoch 230 	 Loss=29.91 	 Bias=16.34 	 learning_rate=0.1903
# Epoch 240 	 Loss=29.89 	 Bias=16.29 	 learning_rate=0.1884
# Epoch 250 	 Loss=29.87 	 Bias=16.24 	 learning_rate=0.1865
# Epoch 260 	 Loss=29.86 	 Bias=16.2 	 learning_rate=0.1846
# Epoch 270 	 Loss=29.85 	 Bias=16.16 	 learning_rate=0.1828
# Epoch 280 	 Loss=29.84 	 Bias=16.12 	 learning_rate=0.181
# Epoch 290 	 Loss=29.83 	 Bias=16.08 	 learning_rate=0.1791
# Epoch 300 	 Loss=29.82 	 Bias=16.05 	 learning_rate=0.1773
# Epoch 310 	 Loss=29.81 	 Bias=16.02 	 learning_rate=0.1756
# Epoch 320 	 Loss=29.81 	 Bias=15.99 	 learning_rate=0.1738
# Epoch 330 	 Loss=29.8 	 Bias=15.96 	 learning_rate=0.1721
# Epoch 340 	 Loss=29.8 	 Bias=15.93 	 learning_rate=0.1704
# Epoch 350 	 Loss=29.8 	 Bias=15.91 	 learning_rate=0.1687
# Epoch 360 	 Loss=29.79 	 Bias=15.88 	 learning_rate=0.167
# Epoch 370 	 Loss=29.79 	 Bias=15.86 	 learning_rate=0.1653
# Epoch 380 	 Loss=29.79 	 Bias=15.84 	 learning_rate=0.1636
# Epoch 390 	 Loss=29.78 	 Bias=15.81 	 learning_rate=0.162
# Epoch 400 	 Loss=29.78 	 Bias=15.79 	 learning_rate=0.1604
# Epoch 410 	 Loss=29.78 	 Bias=15.78 	 learning_rate=0.1588
# Epoch 420 	 Loss=29.78 	 Bias=15.76 	 learning_rate=0.1572
# Epoch 430 	 Loss=29.78 	 Bias=15.74 	 learning_rate=0.1556
# Epoch 440 	 Loss=29.78 	 Bias=15.72 	 learning_rate=0.1541
# Epoch 450 	 Loss=29.77 	 Bias=15.71 	 learning_rate=0.1525
# Epoch 460 	 Loss=29.77 	 Bias=15.69 	 learning_rate=0.151
# Epoch 470 	 Loss=29.77 	 Bias=15.68 	 learning_rate=0.1495
# Epoch 480 	 Loss=29.77 	 Bias=15.66 	 learning_rate=0.148
# Epoch 490 	 Loss=29.77 	 Bias=15.65 	 learning_rate=0.1465

# %%
len(loss_list),LOSS,W,B,len(W)
# Out:
# (500,
#  29.769474,
#  array([[ -7.75342  ],
#         [  1.4333652],
#         [ -1.4214492],
#         [  1.3055378],
#         [ 25.839941 ],
#         [-21.011003 ]], dtype=float32),
#  15.637014,
#  6)

# %%
plt.plot(range(len(loss_list)), loss_list, color="red")
plt.show()

# %%
plt.plot(range(len(predict_list)), predict_list, color="red")
plt.plot(range(len(target_list)), target_list, color="green")
plt.show()
